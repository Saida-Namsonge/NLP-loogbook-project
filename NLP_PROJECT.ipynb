# %% [markdown]
# <a href="https://colab.research.google.com/github/Saida-Namsonge/NLP-loogbook-project/blob/main/NLP_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
# Tokenization using NLTK
from nltk import word_tokenize, sent_tokenize
sent = "GeeksforGeeks is a great learning platform.\
It is one of the best for Computer Science students."
print(word_tokenize(sent))
print(sent_tokenize(sent))
# Out:
# ['GeeksforGeeks', 'is', 'a', 'great', 'learning', 'platform.It', 'is', 'one', 'of', 'the', 'best', 'for', 'Computer', 'Science', 'students', '.']
# ['GeeksforGeeks is a great learning platform.It is one of the best for Computer Science students.']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')

# Sample text
text = "This is a sample sentence showing stopword removal."

# Get English stopwords and tokenize
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text.lower())

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]

print("Original:", tokens)
print("Filtered:", filtered_tokens)
# Out:
# Original: ['this', 'is', 'a', 'sample', 'sentence', 'showing', 'stopword', 'removal', '.']
# Filtered: ['sample', 'sentence', 'showing', 'stopword', 'removal', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.util import bigrams
from nltk.tokenize import word_tokenize

# Download tokenizer
nltk.download('punkt')

# Sample text
text = "Natural Language Processing is interesting"

# Tokenize sentence
tokens = word_tokenize(text)

# Generate bigrams
bigram_output = list(bigrams(tokens))

# Display output
print(bigram_output)
# Out:
# [('Natural', 'Language'), ('Language', 'Processing'), ('Processing', 'is'), ('is', 'interesting')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.util import trigrams
from nltk.tokenize import word_tokenize

# Download tokenizer
nltk.download('punkt')

# Sample text
text = "Natural Language Processing is interesting"

# Tokenize sentence
tokens = word_tokenize(text)

# Generate trigrams
trigram_output = list(trigrams(tokens))

# Display output
print(trigram_output)
# Out:
# [('Natural', 'Language', 'Processing'), ('Language', 'Processing', 'is'), ('Processing', 'is', 'interesting')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
text = "NLTK is a powerful library for natural language processing."
words = word_tokenize(text)

pos_tags = pos_tag(words)
print("Original Text:")
print(text)

print("\nPoS Tagging Result:")
for word, pos_tag in pos_tags:
    print(f"{word}: {pos_tag}")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Original Text:
# NLTK is a powerful library for natural language processing.
#
# PoS Tagging Result:
# NLTK: NNP
# is: VBZ
# a: DT
# powerful: JJ
# library: NN
# for: IN
# natural: JJ
# language: NN
# processing: NN
# .: .

# %%
from collections import defaultdict
from nltk.tokenize import word_tokenize
import nltk


nltk.download('punkt')


text = "I love studying Natural Language Processing"


tokens = word_tokenize(text)

# Build prediction dictionary
prediction = defaultdict(list)

for i in range(len(tokens) - 1):
    prediction[tokens[i]].append(tokens[i + 1])

# Display predictions
for word in prediction:
    print(word, "->", prediction[word])
# Out:
# I -> ['love']
# love -> ['studying']
# studying -> ['Natural']
# Natural -> ['Language']
# Language -> ['Processing']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag


nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')


text = "Natural Language Processing is transforming the world of Artificial Intelligence. It is a key area of AI."


sentences = sent_tokenize(text)




for i, sent in enumerate(sentences, start=1):
    print(f"\nSentence {i}: {sent}")


    tokens = word_tokenize(sent)


    tagged = pos_tag(tokens)

    print("\nWord-by-word analysis:")


    for word, tag in tagged:
        print(f"{word:15} -> {tag}")
# Out:
# Sentence 1: Natural Language Processing is transforming the world of Artificial Intelligence.
#
# Word-by-word analysis:
# Natural         -> JJ
# Language        -> NNP
# Processing      -> NNP
# is              -> VBZ
# transforming    -> VBG
# the             -> DT
# world           -> NN
# of              -> IN
# Artificial      -> JJ
# Intelligence    -> NNP
# .               -> .
#
# Sentence 2: It is a key area of AI.
#
# Word-by-word analysis:
# It              -> PRP
# is              -> VBZ
# a               -> DT
# key             -> JJ
# area            -> NN
# of              -> IN
# AI              -> NNP
# .               -> .
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
import random
from nltk.corpus import treebank
from nltk.tag import hmm

nltk.download('treebank')


tagged_sentences = treebank.tagged_sents()


train_data = tagged_sentences[:3000]
test_data = tagged_sentences[3000:]


trainer = hmm.HiddenMarkovModelTrainer()
hmm_model = trainer.train(train_data)


sentence = "The president visited Nairobi".split()


print("Sequence Labeling Output:")
print(hmm_model.tag(sentence))
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# Sequence Labeling Output:
# [('The', 'DT'), ('president', 'NN'), ('visited', 'VBD'), ('Nairobi', 'NNP')]

# %%
print(hmm_model.evaluate(test_data))
# Out:
# /tmp/ipykernel_2882/707368618.py:1: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(hmm_model.evaluate(test_data))
# 0.36844377293330455

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import hmm
nltk.download('treebank')
tagged_sentences = treebank.tagged_sents()
print("Total sentences in dataset:", len(tagged_sentences))
train_data = tagged_sentences[:3000]
test_data = tagged_sentences[3000:]
print("Training sentences:", len(train_data))
print("Testing sentences:", len(test_data))
trainer = hmm.HiddenMarkovModelTrainer()
hmm_model = trainer.train(train_data)
sentence = "The president visited Nairobi".split()
tagged_output = hmm_model.tag(sentence)
for word, tag in tagged_output:
    print(f"{word:15} -> {tag}")
sentence2 = "Natural Language Processing is powerful".split()
print(hmm_model.tag(sentence2))
accuracy = hmm_model.evaluate(test_data)
print("Accuracy:", accuracy)
print(hmm_model.probability(train_data[0]))
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# Total sentences in dataset: 3914
# Training sentences: 3000
# Testing sentences: 914
# The             -> DT
# president       -> NN
# visited         -> VBD
# Nairobi         -> NNP
# [('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP'), ('is', 'NNP'), ('powerful', 'NNP')]
# /tmp/ipykernel_2882/1127482923.py:19: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = hmm_model.evaluate(test_data)
# Accuracy: 0.36844377293330455
# 1.1129179393023502e-52

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
text = "Barack Obama was born in Hawaii in 1961."
tokens = word_tokenize(text)
tags = pos_tag(tokens)
entities = ne_chunk(tags)
print(entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP)
#   in/IN
#   1961/CD
#   ./.)

# %%
from nltk.corpus import treebank

print(treebank.tagged_sents()[0])
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')]

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "The lecturer teaches Natural Language Processing."

doc = nlp(text)

for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# The det lecturer
# lecturer nsubj teaches
# teaches ROOT teaches
# Natural compound Language
# Language compound Processing
# Processing dobj teaches
# . punct teaches

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

sentence1 = nlp("The student passed the examination")

sentence2 = nlp("The learner succeeded in the exam")

similarity = sentence1.similarity(sentence2)

print(similarity)
# Out:
# 0.7735585570335388
# /tmp/ipykernel_4884/1860603024.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = sentence1.similarity(sentence2)

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 57.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy


nlp = spacy.load("en_core_web_md")


sentence1 = "I love eating apples"
sentence2 = "I enjoy consuming fruits"


doc1 = nlp(sentence1)
doc2 = nlp(sentence2)


similarity_score = doc1.similarity(doc2)

print(f"Sentence 1: {sentence1}")
print(f"Sentence 2: {sentence2}")
print(f"Semantic similarity: {similarity_score:.3f}")
# Out:
# Sentence 1: I love eating apples
# Sentence 2: I enjoy consuming fruits
# Semantic similarity: 0.811

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text1 = "The administrator updated student records"
doc1 = nlp(text1)

print("Sentence 1:", text1)
print("-" * 40)
for token in doc1:
    print(f"{token.text:15} {token.dep_:12} {token.head.text:15}")
# Out:
# Sentence 1: The administrator updated student records
# ----------------------------------------
# The             det          administrator
# administrator   nsubj        updated
# updated         ROOT         updated
# student         compound     records
# records         dobj         updated

# %%
text2 = "Machine learning improves language processing"
doc2 = nlp(text2)

print("\nSentence 2:", text2)
print("-" * 40)
for token in doc2:
    print(f"{token.text:15} {token.dep_:12} {token.head.text:15}")
# Out:
# Sentence 2: Machine learning improves language processing
# ----------------------------------------
# Machine         compound     learning
# learning        nsubj        improves
# improves        ROOT         improves
# language        compound     processing
# processing      dobj         improves

# %%
import spacy


nlp = spacy.load("en_core_web_md")


similar1 = "The cat sleeps on the sofa"
similar2 = "The feline rests on the couch"


unrelated1 = "The cat sleeps on the sofa"
unrelated2 = "The stock market crashed today"


doc_sim1 = nlp(similar1)
doc_sim2 = nlp(similar2)
doc_unrel1 = nlp(unrelated1)
doc_unrel2 = nlp(unrelated2)

similarity_score = doc_sim1.similarity(doc_sim2)
unrelated_score = doc_unrel1.similarity(doc_unrel2)


print("SEMANTIC SIMILARITY COMPARISON")


print("\nPair 1 - SIMILAR Sentences:")
print(f"  A: '{similar1}'")
print(f"  B: '{similar2}'")
print(f"  Similarity Score: {similarity_score:.3f}")

print("\nPair 2 - UNRELATED Sentences:")
print(f"  A: '{unrelated1}'")
print(f"  B: '{unrelated2}'")
print(f"  Similarity Score: {unrelated_score:.3f}")


print("RESULTS:")
# Out:
# SEMANTIC SIMILARITY COMPARISON
#
# Pair 1 - SIMILAR Sentences:
#   A: 'The cat sleeps on the sofa'
#   B: 'The feline rests on the couch'
#   Similarity Score: 0.806
#
# Pair 2 - UNRELATED Sentences:
#   A: 'The cat sleeps on the sofa'
#   B: 'The stock market crashed today'
#   Similarity Score: 0.569
# RESULTS:

# %%
import nltk

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag

text = "Natural Language Processing helps computers understand language."

words = word_tokenize(text)
print("Tokens:", words)

stop_words = set(stopwords.words('english'))
filtered = [w for w in words if w.lower() not in stop_words]
print("Filtered Words:", filtered)

pos = pos_tag(filtered)
print("POS Tags:", pos)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Tokens: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'language', '.']
# Filtered Words: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'language', '.']
# POS Tags: [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'JJ'), ('language', 'NN'), ('.', '.')]

# %%
print("STUDENT ACADEMIC ASSISTANT CHATBOT")
print("Type 'bye' to exit")

while True:
    user = input("\nYou: ").lower()

    # Greetings
    if user in ["hello", "hi", "hey"]:
        print("Bot: Hello Student! How can I help you today?")

    # CAT Schedule Questions
    elif "cat" in user or "exam" in user:
        print("Bot: CAT 1 starts next week. Please check the class timetable for exact dates.")

    # Unit Registration Questions
    elif "registration" in user or "register" in user:
        print("Bot: Unit registration is currently open. Please use the student portal to register your units.")

    # Exit Command
    elif user == "bye":
        print("Bot: Goodbye! Have a great day.")
        break

    # Unknown Input
    else:
        print("Bot: Sorry, I do not understand your question.")
# Out:
# STUDENT ACADEMIC ASSISTANT CHATBOT
# Type 'bye' to exit
#
# You: hello
# Bot: Hello Student! How can I help you today?
#
# You: cat
# Bot: CAT 1 starts next week. Please check the class timetable for exact dates.
#
# You: unit registration
# Bot: Unit registration is currently open. Please use the student portal to register your units.
#
# You: bye
# Bot: Goodbye! Have a great day.
